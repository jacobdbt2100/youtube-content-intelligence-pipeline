# %% [markdown]
# # Setup Infrastructure

# %% [markdown]
# ## Create Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS youtube_content_intelligence;

# %% [markdown]
# ## Create Schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS youtube_content_intelligence.bronze;

CREATE SCHEMA IF NOT EXISTS youtube_content_intelligence.silver;

CREATE SCHEMA IF NOT EXISTS youtube_content_intelligence.gold;

# %% [markdown]
# ## Verify

# %%
# %sql
SHOW SCHEMAS IN youtube_content_intelligence;
